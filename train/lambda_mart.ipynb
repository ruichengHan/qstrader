# %%
import os
import pandas as pd
from pandas import DataFrame
import talib

from lightgbm import LGBMRanker

# %%
def cal_code_feature(df: DataFrame):
    # 计算RSI指标
    df['RSI2'] = talib.RSI(df['close'], timeperiod=2) / 100
    df['RSI5'] = talib.RSI(df['close'], timeperiod=5) / 100
    df['RSI10'] = talib.RSI(df['close'], timeperiod=10) / 100
def read_data(csv_dir: str):
    dataframes = {}
    for filename in os.listdir(csv_dir):
        if filename.endswith('.csv'):
            file_path = os.path.join(csv_dir, filename)
            try:
                df = pd.read_csv(file_path)
                df['ret5'] = (df['close'].shift(-5) - df['close']) / df['close']
                df = df[df["date"] < "2024-12-20"]
                df = df[df["date"] > "2016-02-01"]
                # 过滤ret5为NAN的数据
                df = df.dropna(subset=['ret5'])

                cal_code_feature(df)
                df = df.drop("Unnamed: 0", axis=1)

                dataframes[filename] = df
                print(f"成功读取文件: {filename}, 形状: {df.shape}")
            except Exception as e:
                print(f"读取文件 {filename} 时出错: {e}")
    # 将所有DataFrame进行union操作
    all_data = pd.concat(dataframes.values(), ignore_index=True)
    return all_data

# %%
csv_dir = '/Users/rui.chengcr/PycharmProjects/qstrader/qs_data/price/'
all_data = read_data(csv_dir)
# Out:
# 成功读取文件: 600909.csv, 形状: (1948, 16)
# 成功读取文件: 600048.csv, 形状: (2151, 16)
# 成功读取文件: 600060.csv, 形状: (2157, 16)
# 成功读取文件: 300724.csv, 形状: (1543, 16)
# 成功读取文件: 688002.csv, 形状: (1315, 16)
# 成功读取文件: 601168.csv, 形状: (1965, 16)
# 成功读取文件: 600276.csv, 形状: (2157, 16)
# 成功读取文件: 603019.csv, 形状: (2155, 16)
# 成功读取文件: 000987.csv, 形状: (2049, 16)
# 成功读取文件: 000039.csv, 形状: (2153, 16)
# 成功读取文件: 300122.csv, 形状: (2158, 16)
# 成功读取文件: 300136.csv, 形状: (2158, 16)
# 成功读取文件: 000830.csv, 形状: (2148, 16)
# 成功读取文件: 600316.csv, 形状: (2158, 16)
# 成功读取文件: 600699.csv, 形状: (2133, 16)
# 成功读取文件: 000401.csv, 形状: (2018, 16)
# 成功读取文件: 601236.csv, 形状: (1320, 16)
# 成功读取文件: 600115.csv, 形状: (2157, 16)
# 成功读取文件: 600673.csv, 形状: (1884, 16)
# 成功读取文件: 002203.csv, 形状: (2147, 16)
# 成功读取文件: 601009.csv, 形状: (2156, 16)
# 成功读取文件: 002001.csv, 形状: (2154, 16)
# 成功读取文件: 601021.csv, 形状: (2151, 16)
# 成功读取文件: 688188.csv, 形状: (1302, 16)
# 成功读取文件: 000825.csv, 形状: (2050, 16)
# 成功读取文件: 688981.csv, 形状: (1076, 16)
# 成功读取文件: 601169.csv, 形状: (2150, 16)
# 成功读取文件: 600511.csv, 形状: (2037, 16)
# 成功读取文件: 601633.csv, 形状: (2151, 16)
# 成功读取文件: 000776.csv, 形状: (2158, 16)
# 成功读取文件: 601800.csv, 形状: (2158, 16)
# 成功读取文件: 600061.csv, 形状: (2147, 16)
# 成功读取文件: 603568.csv, 形状: (2158, 16)
# 成功读取文件: 600707.csv, 形状: (2142, 16)
# 成功读取文件: 002439.csv, 形状: (2089, 16)
# 成功读取文件: 600739.csv, 形状: (2138, 16)
# 成功读取文件: 601816.csv, 形状: (1194, 16)
# 成功读取文件: 600329.csv, 形状: (2153, 16)
# 成功读取文件: 601989.csv, 形状: (2019, 16)
# 成功读取文件: 000166.csv, 形状: (2133, 16)
# 成功读取文件: 600895.csv, 形状: (2158, 16)
# 成功读取文件: 603379.csv, 形状: (1389, 16)
# 成功读取文件: 002572.csv, 形状: (2158, 16)
# 成功读取文件: 300450.csv, 形状: (2009, 16)
# 成功读取文件: 603392.csv, 形状: (1127, 16)
# 成功读取文件: 000629.csv, 形状: (1748, 16)
# 成功读取文件: 601988.csv, 形状: (2158, 16)
# 成功读取文件: 603806.csv, 形状: (2158, 16)
# 成功读取文件: 601618.csv, 形状: (2158, 16)
# 成功读取文件: 601156.csv, 形状: (858, 16)
# 成功读取文件: 600704.csv, 形状: (2158, 16)
# 成功读取文件: 600062.csv, 形状: (2158, 16)
# 成功读取文件: 603225.csv, 形状: (1867, 16)
# 成功读取文件: 000563.csv, 形状: (2077, 16)
# 成功读取文件: 000598.csv, 形状: (2158, 16)
# 成功读取文件: 300285.csv, 形状: (2058, 16)
# 成功读取文件: 603786.csv, 形状: (1260, 16)
# 成功读取文件: 600516.csv, 形状: (2156, 16)
# 成功读取文件: 601608.csv, 形状: (2087, 16)
# 成功读取文件: 300124.csv, 形状: (2147, 16)
# 成功读取文件: 601998.csv, 形状: (2158, 16)
# 成功读取文件: 600660.csv, 形状: (2158, 16)
# 成功读取文件: 600885.csv, 形状: (2158, 16)
# 成功读取文件: 601225.csv, 形状: (2158, 16)
# 成功读取文件: 002563.csv, 形状: (2158, 16)
# 成功读取文件: 600339.csv, 形状: (2003, 16)
# 成功读取文件: 002007.csv, 形状: (2158, 16)
# 成功读取文件: 603195.csv, 形状: (1185, 16)
# 成功读取文件: 002601.csv, 形状: (2118, 16)
# 成功读取文件: 000002.csv, 形状: (2053, 16)
# 成功读取文件: 600517.csv, 形状: (2147, 16)
# 成功读取文件: 002371.csv, 形状: (2153, 16)
# 成功读取文件: 600926.csv, 形状: (1982, 16)
# 成功读取文件: 300251.csv, 形状: (2124, 16)
# 成功读取文件: 600918.csv, 形状: (1105, 16)
# 成功读取文件: 601390.csv, 形状: (2084, 16)
# 成功读取文件: 002429.csv, 形状: (2128, 16)
# 成功读取文件: 002373.csv, 形状: (2017, 16)
# 成功读取文件: 002415.csv, 形状: (2156, 16)
# 成功读取文件: 600298.csv, 形状: (2158, 16)
# 成功读取文件: 601186.csv, 形状: (2158, 16)
# 成功读取文件: 601838.csv, 形状: (1670, 16)
# 成功读取文件: 601179.csv, 形状: (2158, 16)
# 成功读取文件: 600529.csv, 形状: (2158, 16)
# 成功读取文件: 601958.csv, 形状: (2158, 16)
# 成功读取文件: 600663.csv, 形状: (2036, 16)
# 成功读取文件: 600111.csv, 形状: (2158, 16)
# 成功读取文件: 600887.csv, 形状: (2134, 16)
# 成功读取文件: 600893.csv, 形状: (2127, 16)
# 成功读取文件: 601555.csv, 形状: (2144, 16)
# 成功读取文件: 600886.csv, 形状: (2158, 16)
# 成功读取文件: 600845.csv, 形状: (2156, 16)
# 成功读取文件: 600879.csv, 形状: (2149, 16)
# 成功读取文件: 002945.csv, 形状: (1437, 16)
# 成功读取文件: 000001.csv, 形状: (2158, 16)
# 成功读取文件: 600528.csv, 形状: (2152, 16)
# 成功读取文件: 688012.csv, 形状: (1315, 16)
# 成功读取文件: 600500.csv, 形状: (2133, 16)
# 成功读取文件: 000997.csv, 形状: (2094, 16)
# 成功读取文件: 600299.csv, 形状: (2158, 16)
# 成功读取文件: 002831.csv, 形状: (1946, 16)
# 成功读取文件: 002372.csv, 形状: (2158, 16)
# 成功读取文件: 000559.csv, 形状: (2143, 16)
# 成功读取文件: 600919.csv, 形状: (2031, 16)
# 成功读取文件: 600956.csv, 形状: (1089, 16)
# 成功读取文件: 600765.csv, 形状: (2148, 16)
# 成功读取文件: 300009.csv, 形状: (2158, 16)
# 成功读取文件: 600598.csv, 形状: (2158, 16)
# 成功读取文件: 000728.csv, 形状: (2132, 16)
# 成功读取文件: 002739.csv, 形状: (1754, 16)
# 成功读取文件: 003816.csv, 形状: (1290, 16)
# 成功读取文件: 603456.csv, 形状: (2135, 16)
# 成功读取文件: 002507.csv, 形状: (2029, 16)
# 成功读取文件: 000338.csv, 形状: (2156, 16)
# 成功读取文件: 600177.csv, 形状: (2158, 16)
# 成功读取文件: 600176.csv, 形状: (2146, 16)
# 成功读取文件: 600837.csv, 形状: (2141, 16)
# 成功读取文件: 600406.csv, 形状: (2049, 16)
# 成功读取文件: 600348.csv, 形状: (2158, 16)
# 成功读取文件: 000661.csv, 形状: (2143, 16)
# 成功读取文件: 600566.csv, 形状: (2158, 16)
# 成功读取文件: 000729.csv, 形状: (2158, 16)
# 成功读取文件: 002670.csv, 形状: (2079, 16)
# 成功读取文件: 601888.csv, 形状: (2158, 16)
# 成功读取文件: 000932.csv, 形状: (2037, 16)
# 成功读取文件: 601877.csv, 形状: (2152, 16)
# 成功读取文件: 600764.csv, 形状: (1907, 16)
# 成功读取文件: 600016.csv, 形状: (2158, 16)
# 成功读取文件: 002466.csv, 形状: (2132, 16)
# 成功读取文件: 600028.csv, 形状: (2158, 16)
# 成功读取文件: 601336.csv, 形状: (2158, 16)
# 成功读取文件: 300750.csv, 形状: (1586, 16)
# 成功读取文件: 002128.csv, 形状: (2041, 16)
# 成功读取文件: 600570.csv, 形状: (2156, 16)
# 成功读取文件: 603858.csv, 形状: (1966, 16)
# 成功读取文件: 000878.csv, 形状: (2139, 16)
# 成功读取文件: 601901.csv, 形状: (2148, 16)
# 成功读取文件: 600438.csv, 形状: (2095, 16)
# 成功读取文件: 000887.csv, 形状: (2038, 16)
# 成功读取文件: 600809.csv, 形状: (2146, 16)
# 成功读取文件: 300383.csv, 形状: (2048, 16)
# 成功读取文件: 600808.csv, 形状: (2158, 16)
# 成功读取文件: 600820.csv, 形状: (2158, 16)
# 成功读取文件: 002049.csv, 形状: (2019, 16)
# 成功读取文件: 601928.csv, 形状: (2158, 16)
# 成功读取文件: 002129.csv, 形状: (1751, 16)
# 成功读取文件: 002673.csv, 形状: (2144, 16)
# 成功读取文件: 300037.csv, 形状: (2158, 16)
# 成功读取文件: 600015.csv, 形状: (2158, 16)
# 成功读取文件: 002459.csv, 形状: (2086, 16)
# 成功读取文件: 003035.csv, 形状: (950, 16)
# 成功读取文件: 600029.csv, 形状: (2155, 16)
# 成功读取文件: 600968.csv, 形状: (1333, 16)
# 成功读取文件: 000538.csv, 形状: (1994, 16)
# 成功读取文件: 600011.csv, 形状: (2158, 16)
# 成功读取文件: 002475.csv, 形状: (2157, 16)
# 成功读取文件: 300033.csv, 形状: (2157, 16)
# 成功读取文件: 300782.csv, 形状: (1339, 16)
# 成功读取文件: 000060.csv, 形状: (2157, 16)
# 成功读取文件: 600398.csv, 形状: (2153, 16)
# 成功读取文件: 600373.csv, 形状: (2155, 16)
# 成功读取文件: 002065.csv, 形状: (2048, 16)
# 成功读取文件: 000100.csv, 形状: (1992, 16)
# 成功读取文件: 603444.csv, 形状: (1934, 16)
# 成功读取文件: 002273.csv, 形状: (2158, 16)
# 成功读取文件: 002266.csv, 形状: (2059, 16)
# 成功读取文件: 002500.csv, 形状: (2152, 16)
# 成功读取文件: 600170.csv, 形状: (2138, 16)
# 成功读取文件: 002299.csv, 形状: (2102, 16)
# 成功读取文件: 000883.csv, 形状: (2158, 16)
# 成功读取文件: 601939.csv, 形状: (2158, 16)
# 成功读取文件: 002138.csv, 形状: (2158, 16)
# 成功读取文件: 601118.csv, 形状: (2036, 16)
# 成功读取文件: 601865.csv, 形状: (1421, 16)
# 成功读取文件: 688099.csv, 形状: (1302, 16)
# 成功读取文件: 002460.csv, 形状: (2155, 16)
# 成功读取文件: 600038.csv, 形状: (2148, 16)
# 成功读取文件: 600010.csv, 形状: (2149, 16)
# 成功读取文件: 601318.csv, 形状: (2158, 16)
# 成功读取文件: 600760.csv, 形状: (2076, 16)
# 成功读取文件: 000513.csv, 形状: (2154, 16)
# 成功读取文件: 601456.csv, 形状: (1045, 16)
# 成功读取文件: 002304.csv, 形状: (2158, 16)
# 成功读取文件: 300024.csv, 形状: (2158, 16)
# 成功读取文件: 601668.csv, 形状: (2158, 16)
# 成功读取文件: 000739.csv, 形状: (2158, 16)
# 成功读取文件: 601898.csv, 形状: (2158, 16)
# 成功读取文件: 000063.csv, 形状: (2087, 16)
# 成功读取文件: 000895.csv, 形状: (2143, 16)
# 成功读取文件: 002714.csv, 形状: (2148, 16)
# 成功读取文件: 300408.csv, 形状: (2148, 16)
# 成功读取文件: 600600.csv, 形状: (2158, 16)
# 成功读取文件: 600166.csv, 形状: (2154, 16)
# 成功读取文件: 002271.csv, 形状: (2158, 16)
# 成功读取文件: 300347.csv, 形状: (2125, 16)
# 成功读取文件: 688111.csv, 形状: (1236, 16)
# 成功读取文件: 603650.csv, 形状: (1575, 16)
# 成功读取文件: 002926.csv, 形状: (1667, 16)
# 成功读取文件: 601899.csv, 形状: (2152, 16)
# 成功读取文件: 603056.csv, 形状: (1670, 16)
# 成功读取文件: 600563.csv, 形状: (2158, 16)
# 成功读取文件: 601669.csv, 形状: (2149, 16)
# 成功读取文件: 600588.csv, 形状: (2156, 16)
# 成功读取文件: 601866.csv, 形状: (2142, 16)
# 成功读取文件: 000937.csv, 形状: (2158, 16)
# 成功读取文件: 002311.csv, 形状: (2158, 16)
# 成功读取文件: 601319.csv, 形状: (1479, 16)
# 成功读取文件: 000537.csv, 形状: (2085, 16)
# 成功读取文件: 600036.csv, 形状: (2158, 16)
# 成功读取文件: 601328.csv, 形状: (2158, 16)
# 成功读取文件: 603259.csv, 形状: (1610, 16)
# 成功读取文件: 601857.csv, 形状: (2158, 16)
# 成功读取文件: 300014.csv, 形状: (2158, 16)
# 成功读取文件: 600585.csv, 形状: (2158, 16)
# 成功读取文件: 600208.csv, 形状: (2154, 16)
# 成功读取文件: 000709.csv, 形状: (2158, 16)
# 成功读取文件: 601880.csv, 形状: (2141, 16)
# 成功读取文件: 600546.csv, 形状: (2111, 16)
# 成功读取文件: 601658.csv, 形状: (1220, 16)
# 成功读取文件: 002056.csv, 形状: (2158, 16)
# 成功读取文件: 600426.csv, 形状: (2158, 16)
# 成功读取文件: 603885.csv, 形状: (2158, 16)
# 成功读取文件: 002532.csv, 形状: (2075, 16)
# 成功读取文件: 002268.csv, 形状: (2158, 16)
# 成功读取文件: 600157.csv, 形状: (1945, 16)
# 成功读取文件: 002241.csv, 形状: (2158, 16)
# 成功读取文件: 600369.csv, 形状: (2156, 16)
# 成功读取文件: 000898.csv, 形状: (2157, 16)
# 成功读取文件: 601088.csv, 形状: (2094, 16)
# 成功读取文件: 002916.csv, 形状: (1702, 16)
# 成功读取文件: 600547.csv, 形状: (2128, 16)
# 成功读取文件: 601881.csv, 形状: (1921, 16)
# 成功读取文件: 000708.csv, 形状: (2152, 16)
# 成功读取文件: 601665.csv, 形状: (852, 16)
# 成功读取文件: 300001.csv, 形状: (2154, 16)
# 成功读取文件: 600584.csv, 形状: (2077, 16)
# 成功读取文件: 300015.csv, 形状: (2142, 16)
# 成功读取文件: 603927.csv, 形状: (1280, 16)
# 成功读取文件: 600745.csv, 形状: (1903, 16)
# 成功读取文件: 600989.csv, 形状: (1361, 16)
# 成功读取文件: 600009.csv, 形状: (2147, 16)
# 成功读取文件: 300759.csv, 形状: (1430, 16)
# 成功读取文件: 002690.csv, 形状: (2158, 16)
# 成功读取文件: 601868.csv, 形状: (782, 16)
# 成功读取文件: 601698.csv, 形状: (1331, 16)
# 成功读取文件: 300017.csv, 形状: (2140, 16)
# 成功读取文件: 002653.csv, 形状: (2158, 16)
# 成功读取文件: 000050.csv, 形状: (2028, 16)
# 成功读取文件: 600380.csv, 形状: (2135, 16)
# 成功读取文件: 002294.csv, 形状: (2158, 16)
# 成功读取文件: 300413.csv, 形状: (1898, 16)
# 成功读取文件: 601288.csv, 形状: (2158, 16)
# 成功读取文件: 001979.csv, 形状: (2142, 16)
# 成功读取文件: 600155.csv, 形状: (2151, 16)
# 成功读取文件: 600141.csv, 形状: (2152, 16)
# 成功读取文件: 000333.csv, 形状: (2108, 16)
# 成功读取文件: 600183.csv, 形状: (2158, 16)
# 成功读取文件: 600801.csv, 形状: (2156, 16)
# 成功读取文件: 002281.csv, 形状: (2158, 16)
# 成功读取文件: 600418.csv, 形状: (2156, 16)
# 成功读取文件: 000858.csv, 形状: (2158, 16)
# 成功读取文件: 601128.csv, 形状: (1996, 16)
# 成功读取文件: 601100.csv, 形状: (2158, 16)
# 成功读取文件: 000938.csv, 形状: (2123, 16)
# 成功读取文件: 600008.csv, 形状: (2142, 16)
# 成功读取文件: 002444.csv, 形状: (2158, 16)
# 成功读取文件: 603501.csv, 形状: (1685, 16)
# 成功读取文件: 603288.csv, 形状: (2158, 16)
# 成功读取文件: 600959.csv, 形状: (2056, 16)
# 成功读取文件: 000519.csv, 形状: (2151, 16)
# 成功读取文件: 600030.csv, 形状: (2141, 16)
# 成功读取文件: 600018.csv, 形状: (2155, 16)
# 成功读取文件: 300760.csv, 形状: (1502, 16)
# 成功读取文件: 601138.csv, 形状: (1587, 16)
# 成功读取文件: 603707.csv, 形状: (1804, 16)
# 成功读取文件: 002939.csv, 形状: (1494, 16)
# 成功读取文件: 300628.csv, 形状: (1887, 16)
# 成功读取文件: 601919.csv, 形状: (2108, 16)
# 成功读取文件: 603868.csv, 形状: (2110, 16)
# 成功读取文件: 603883.csv, 形状: (2122, 16)
# 成功读取文件: 002078.csv, 形状: (2149, 16)
# 成功读取文件: 001203.csv, 形状: (880, 16)
# 成功读取文件: 600346.csv, 形状: (2051, 16)
# 成功读取文件: 688126.csv, 形状: (1134, 16)
# 成功读取文件: 002736.csv, 形状: (2148, 16)
# 成功读取文件: 600839.csv, 形状: (2158, 16)
# 成功读取文件: 600150.csv, 形状: (2021, 16)
# 成功读取文件: 002508.csv, 形状: (2158, 16)
# 成功读取文件: 002252.csv, 形状: (1849, 16)
# 成功读取文件: 600637.csv, 形状: (2149, 16)
# 成功读取文件: 601717.csv, 形状: (1994, 16)
# 成功读取文件: 600435.csv, 形状: (2158, 16)
# 成功读取文件: 002938.csv, 形状: (1516, 16)
# 成功读取文件: 600390.csv, 形状: (2037, 16)
# 成功读取文件: 601111.csv, 形状: (2157, 16)
# 成功读取文件: 603712.csv, 形状: (1654, 16)
# 成功读取文件: 601139.csv, 形状: (2157, 16)
# 成功读取文件: 601878.csv, 形状: (1821, 16)
# 成功读取文件: 601688.csv, 形状: (2158, 16)
# 成功读取文件: 600582.csv, 形状: (2158, 16)
# 成功读取文件: 600019.csv, 形状: (2066, 16)
# 成功读取文件: 600031.csv, 形状: (2158, 16)
# 成功读取文件: 600025.csv, 形状: (1702, 16)
# 成功读取文件: 600970.csv, 形状: (2134, 16)
# 成功读取文件: 600958.csv, 形状: (2146, 16)
# 成功读取文件: 600755.csv, 形状: (2157, 16)
# 成功读取文件: 600999.csv, 形状: (2152, 16)
# 成功读取文件: 688521.csv, 形状: (1053, 16)
# 成功读取文件: 600580.csv, 形状: (2145, 16)
# 成功读取文件: 601098.csv, 形状: (2158, 16)
# 成功读取文件: 600392.csv, 形状: (2153, 16)
# 成功读取文件: 002709.csv, 形状: (2148, 16)
# 成功读取文件: 600153.csv, 形状: (2072, 16)
# 成功读取文件: 002244.csv, 形状: (2158, 16)
# 成功读取文件: 000651.csv, 形状: (2001, 16)
# 成功读取文件: 601066.csv, 形状: (1580, 16)
# 成功读取文件: 600436.csv, 形状: (2158, 16)
# 成功读取文件: 601728.csv, 形状: (807, 16)
# 成功读取文件: 603659.csv, 形状: (1676, 16)
# 成功读取文件: 000876.csv, 形状: (2136, 16)
# 成功读取文件: 603077.csv, 形状: (2146, 16)
# 成功读取文件: 000725.csv, 形状: (2158, 16)
# 成功读取文件: 601106.csv, 形状: (2150, 16)
# 成功读取文件: 002683.csv, 形状: (2143, 16)
# 成功读取文件: 002867.csv, 形状: (1860, 16)
# 成功读取文件: 300212.csv, 形状: (2059, 16)
# 成功读取文件: 600928.csv, 形状: (1411, 16)
# 成功读取文件: 601377.csv, 形状: (2146, 16)
# 成功读取文件: 000568.csv, 形状: (2140, 16)
# 成功读取文件: 601808.csv, 形状: (2158, 16)
# 成功读取文件: 000959.csv, 形状: (2126, 16)
# 成功读取文件: 002155.csv, 形状: (2158, 16)
# 成功读取文件: 600519.csv, 形状: (2158, 16)
# 成功读取文件: 603986.csv, 形状: (1819, 16)
# 成功读取文件: 000636.csv, 形状: (2076, 16)
# 成功读取文件: 601997.csv, 形状: (2027, 16)
# 成功读取文件: 688396.csv, 形状: (1170, 16)
# 成功读取文件: 600690.csv, 形状: (2156, 16)
# 成功读取文件: 300498.csv, 形状: (2157, 16)
# 成功读取文件: 002223.csv, 形状: (2153, 16)
# 成功读取文件: 002236.csv, 形状: (2156, 16)
# 成功读取文件: 601000.csv, 形状: (2143, 16)
# 成功读取文件: 000623.csv, 形状: (2157, 16)
# 成功读取文件: 601766.csv, 形状: (2148, 16)
# 成功读取文件: 601799.csv, 形状: (2158, 16)
# 成功读取文件: 603993.csv, 形状: (2139, 16)
# 成功读取文件: 688036.csv, 形状: (1266, 16)
# 成功读取文件: 002430.csv, 形状: (2144, 16)
# 成功读取文件: 300274.csv, 形状: (2153, 16)
# 成功读取文件: 600901.csv, 形状: (1654, 16)
# 成功读取文件: 000596.csv, 形状: (2158, 16)
# 成功读取文件: 600095.csv, 形状: (2147, 16)
# 成功读取文件: 601360.csv, 形状: (2036, 16)
# 成功读取文件: 002368.csv, 形状: (2140, 16)
# 成功读取文件: 600056.csv, 形状: (2158, 16)
# 成功读取文件: 002195.csv, 形状: (2158, 16)
# 成功读取文件: 000027.csv, 形状: (2158, 16)
# 成功读取文件: 002156.csv, 形状: (2101, 16)
# 成功读取文件: 002142.csv, 形状: (2151, 16)
# 成功读取文件: 688008.csv, 形状: (1315, 16)
# 成功读取文件: 300896.csv, 形状: (1024, 16)
# 成功读取文件: 601016.csv, 形状: (2152, 16)
# 成功读取文件: 300699.csv, 形状: (1772, 16)
# 成功读取文件: 600863.csv, 形状: (2148, 16)
# 成功读取文件: 300316.csv, 形状: (2150, 16)
# 成功读取文件: 601228.csv, 形状: (1879, 16)
# 成功读取文件: 601229.csv, 形状: (1968, 16)
# 成功读取文件: 601598.csv, 形状: (1436, 16)
# 成功读取文件: 600862.csv, 形状: (2158, 16)
# 成功读取文件: 601995.csv, 形状: (1005, 16)
# 成功读取文件: 603833.csv, 形状: (1874, 16)
# 成功读取文件: 000768.csv, 形状: (2158, 16)
# 成功读取文件: 000998.csv, 形状: (2138, 16)
# 成功读取文件: 600282.csv, 形状: (2145, 16)
# 成功读取文件: 000967.csv, 形状: (2095, 16)
# 成功读取文件: 603589.csv, 形状: (2158, 16)
# 成功读取文件: 600906.csv, 形状: (881, 16)
# 成功读取文件: 603228.csv, 形状: (1932, 16)
# 成功读取文件: 002423.csv, 形状: (2007, 16)
# 成功读取文件: 000963.csv, 形状: (2158, 16)
# 成功读取文件: 002812.csv, 形状: (1920, 16)
# 成功读取文件: 000977.csv, 形状: (2145, 16)
# 成功读取文件: 300059.csv, 形状: (2153, 16)
# 成功读取文件: 000778.csv, 形状: (2158, 16)
# 成功读取文件: 002153.csv, 形状: (2148, 16)
# 成功读取文件: 601601.csv, 形状: (2158, 16)
# 成功读取文件: 000988.csv, 形状: (2155, 16)
# 成功读取文件: 002966.csv, 形状: (1306, 16)
# 成功读取文件: 600325.csv, 形状: (2152, 16)
# 成功读取文件: 601985.csv, 形状: (2158, 16)
# 成功读取文件: 002027.csv, 形状: (2158, 16)
# 成功读取文件: 002594.csv, 形状: (2158, 16)
# 成功读取文件: 601211.csv, 形状: (2141, 16)
# 成功读取文件: 002557.csv, 形状: (2158, 16)
# 成功读取文件: 002230.csv, 形状: (2110, 16)
# 成功读取文件: 600126.csv, 形状: (2151, 16)
# 成功读取文件: 601238.csv, 形状: (2148, 16)
# 成功读取文件: 600867.csv, 形状: (2145, 16)
# 成功读取文件: 002595.csv, 形状: (2158, 16)
# 成功读取文件: 300474.csv, 形状: (2114, 16)
# 成功读取文件: 601006.csv, 形状: (2158, 16)
# 成功读取文件: 000625.csv, 形状: (2138, 16)
# 成功读取文件: 000157.csv, 形状: (2158, 16)
# 成功读取文件: 601012.csv, 形状: (2151, 16)
# 成功读取文件: 002797.csv, 形状: (2077, 16)
# 成功读取文件: 601600.csv, 形状: (2049, 16)
# 成功读取文件: 002152.csv, 形状: (2149, 16)
# 成功读取文件: 601166.csv, 形状: (2153, 16)
# 成功读取文件: 601628.csv, 形状: (2158, 16)
# 成功读取文件: 002185.csv, 形状: (2152, 16)
# 成功读取文件: 000786.csv, 形状: (2151, 16)
# 成功读取文件: 300058.csv, 形状: (2158, 16)
# 成功读取文件: 300070.csv, 形状: (2135, 16)
# 成功读取文件: 605499.csv, 形状: (867, 16)
# 成功读取文件: 002385.csv, 形状: (2153, 16)
# 成功读取文件: 600905.csv, 形状: (857, 16)
# 成功读取文件: 600050.csv, 形状: (2063, 16)
# 成功读取文件: 002408.csv, 形状: (2037, 16)
# 成功读取文件: 002352.csv, 形状: (2110, 16)
# 成功读取文件: 000960.csv, 形状: (2143, 16)
# 成功读取文件: 000009.csv, 形状: (2158, 16)
# 成功读取文件: 000021.csv, 形状: (2157, 16)
# 成功读取文件: 000800.csv, 形状: (2147, 16)
# 成功读取文件: 600497.csv, 形状: (2128, 16)
# 成功读取文件: 600332.csv, 形状: (2110, 16)
# 成功读取文件: 601992.csv, 形状: (2148, 16)
# 成功读取文件: 600859.csv, 形状: (1969, 16)
# 成功读取文件: 600871.csv, 形状: (2127, 16)
# 成功读取文件: 600642.csv, 形状: (2158, 16)
# 成功读取文件: 600118.csv, 形状: (2158, 16)
# 成功读取文件: 000425.csv, 形状: (2125, 16)
# 成功读取文件: 002555.csv, 形状: (2030, 16)
# 成功读取文件: 600131.csv, 形状: (2147, 16)
# 成功读取文件: 002019.csv, 形状: (2140, 16)
# 成功读取文件: 002958.csv, 形状: (1394, 16)
# 成功读取文件: 601788.csv, 形状: (2158, 16)
# 成功读取文件: 603000.csv, 形状: (2158, 16)
# 成功读取文件: 600521.csv, 形状: (2158, 16)
# 成功读取文件: 002179.csv, 形状: (2158, 16)
# 成功读取文件: 600535.csv, 形状: (2156, 16)
# 成功读取文件: 601818.csv, 形状: (2157, 16)
# 成功读取文件: 603799.csv, 形状: (2146, 16)
# 成功读取文件: 002353.csv, 形状: (2141, 16)
# 成功读取文件: 002409.csv, 形状: (2001, 16)
# 成功读取文件: 600737.csv, 形状: (2143, 16)
# 成功读取文件: 002384.csv, 形状: (2079, 16)
# 成功读取文件: 601398.csv, 形状: (2158, 16)

# %%
def cal_group_feature(df: DataFrame):
    # 将code列的数据类型转换为int
    df['code'] = df['code'].astype(int)

    # 基于date分组，计算ret5的rank百分比
    df['ret5_rank'] = df.groupby('date')['ret5'].rank(pct=True)
    # 基于date分组，计算RSI2的rank百分比
    df['RSI2_rank'] = df.groupby('date')['RSI2'].rank(pct=True)
    # 基于date分组，计算RSI5的rank百分比
    df['RSI5_rank'] = df.groupby('date')['RSI5'].rank(pct=True)
    # 基于date分组，计算RSI10的rank百分比
    df['RSI10_rank'] = df.groupby('date')['RSI10'].rank(pct=True)

# %%
cal_group_feature(all_data)

# %%
def cal_label(df: DataFrame):

    # 基于date分组，计算ret5的rank，从0开始
    df['label'] = df.groupby('date')['ret5'].rank(pct=True)
    df['label'] = (df['label'] * 16).astype(int)

    # 基于date列对DataFrame进行排序
    df = df.sort_values('date')
    return df

# %%
all_data = cal_label(all_data)

# %%
# 对所有浮点数列保留4位小数
float_columns = all_data.select_dtypes(include=['float64', 'float32']).columns
all_data[float_columns] = all_data[float_columns].round(4)

# %%
def train_model(df: DataFrame):
    print("start to train model")
    model = LGBMRanker(
        objective="lambdarank",
        metric="ndcg",        
        n_estimators=100,
        learning_rate=0.05,
        max_depth=5
    )
    features = ['RSI2_rank', 'RSI5_rank', 'RSI10_rank', 'ret5_rank', 'RSI2', 'RSI5', 'RSI10']
    model.fit(df[features], df['label'], group=df.groupby('date').size().values)
    return model

# %%
train_data = all_data[all_data['date'] <= '2021']

# %%
model = train_model(train_data)
# Out:
# start to train model
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001242 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1785
# [LightGBM] [Info] Number of data points in the train set: 464807, number of used features: 7
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
def predict_model(model, df: DataFrame):
    predict_df = df
    features = ['RSI2_rank', 'RSI5_rank', 'RSI10_rank', 'ret5_rank', 'RSI2', 'RSI5', 'RSI10']
    predict_df['prediction'] = model.predict(predict_df[features])
    return predict_df

# %%
test_data = all_data[all_data['date'] >= '2021-01-01'].copy()

# %%
predict_data = predict_model(model, test_data)

# %%
top_predictions = predict_data.groupby('date').apply(
        lambda x: x.nlargest(30, 'prediction')
    ).reset_index(drop=True)
# Out:
# /var/folders/qd/qm5lw7_10879gddmdz553cth0000gp/T/ipykernel_1637/1696910299.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   top_predictions = predict_data.groupby('date').apply(

# %%
top_predictions[top_predictions["date"]== '2024-01-04']
# Out:
#              date    code    open   close    high     low  adjust_open  \
# 21870  2024-01-04    2466   55.12   53.66   55.12   53.35       472.97
# 21871  2024-01-04  300896  285.00  276.35  286.00  273.01       528.65
# 21872  2024-01-04  603259   69.98   69.16   69.98   68.64       169.67
# 21873  2024-01-04    2352   38.71   38.25   38.75   37.91       124.07
# 21874  2024-01-04  300017    7.93    8.08    8.22    7.75       186.64
# 21875  2024-01-04  600529   26.13   26.22   26.42   25.87       150.96
# 21876  2024-01-04  601717   12.86   13.09   13.12   12.76        30.50
# 21877  2024-01-04     786   24.74   25.10   25.29   24.50       341.40
# 21878  2024-01-04  600563   86.00   86.10   86.92   82.00       152.20
# 21879  2024-01-04  300274   84.47   82.66   84.95   82.47       553.14
# 21880  2024-01-04    2460   41.56   40.72   41.62   40.54       552.03
# 21881  2024-01-04  600438   24.80   24.30   24.87   24.20       238.78
# 21882  2024-01-04  601838   11.22   11.11   11.25   11.05        14.13
# 21883  2024-01-04  601888   80.43   78.60   80.63   77.81       173.95
# 21884  2024-01-04     651   31.90   31.95   32.01   31.45      6632.82
# 21885  2024-01-04    2129   15.00   14.58   15.01   14.38        79.18
# 21886  2024-01-04  600926    9.82    9.76    9.85    9.66        23.30
# 21887  2024-01-04  600690   20.71   20.80   20.86   20.40       797.10
# 21888  2024-01-04  601100   55.82   54.16   56.02   53.71       182.72
# 21889  2024-01-04    2966    6.36    6.29    6.37    6.25         8.08
# 21890  2024-01-04  300014   40.88   39.60   40.88   39.40       708.16
# 21891  2024-01-04  600029    5.74    5.62    5.75    5.59         9.60
# 21892  2024-01-04  603568   16.43   16.47   16.66   16.39        59.88
# 21893  2024-01-04      39    7.90    7.89    7.94    7.80       338.79
# 21894  2024-01-04  601865   25.99   26.22   26.53   25.71        26.75
# 21895  2024-01-04    2557   33.35   32.53   33.44   32.49       102.29
# 21896  2024-01-04  601128    6.30    6.28    6.33    6.25         7.69
# 21897  2024-01-04    2142   19.49   19.08   19.52   18.88        37.91
# 21898  2024-01-04  600018    5.07    5.08    5.15    5.05        82.76
# 21899  2024-01-04  600919    6.71    6.71    6.74    6.66         9.89
#
#        adjust_close  adjust_high  adjust_low  ...    ret5    RSI2    RSI5  \
# 21870        460.53       472.97      457.89  ...  0.1148  0.0980  0.3911
# 21871        513.08       530.45      507.06  ...  0.1598  0.1493  0.4084
# 21872        167.74       169.67      166.52  ...  0.0374  0.0739  0.2389
# 21873        122.69       124.19      121.67  ...  0.0314  0.0957  0.2595
# 21874        189.99       193.13      182.61  ...  0.0446  0.9818  0.8085
# 21875        151.43       152.49      149.58  ...  0.0351  0.9702  0.7838
# 21876         30.96        31.02       30.30  ...  0.0283  0.9336  0.8988
# 21877        345.78       348.10      338.48  ...  0.0279  0.9767  0.8527
# 21878        152.35       153.58      146.20  ...  0.0476  0.2043  0.4197
# 21879        541.41       556.25      540.18  ...  0.0513  0.1248  0.4165
# 21880        541.45       552.79      539.18  ...  0.0933  0.1836  0.4578
# 21881        234.78       239.34      233.98  ...  0.0391  0.2467  0.4972
# 21882         14.02        14.16       13.96  ...  0.0441  0.2156  0.4700
# 21883        170.29       174.35      168.71  ...  0.0441  0.1291  0.3794
# 21884       6639.34      6647.16     6574.14  ...  0.0513  0.5074  0.4528
# 21885         77.02        79.23       75.98  ...  0.0418  0.0975  0.3296
# 21886         23.18        23.36       22.99  ...  0.0359  0.1669  0.4339
# 21887        800.03       801.99      787.00  ...  0.0322  0.4583  0.5277
# 21888        177.56       183.34      176.16  ...  0.0375  0.3461  0.5744
# 21889          8.00         8.09        7.96  ...  0.0525  0.0193  0.2016
# 21890        686.31       708.16      682.90  ...  0.0437  0.1260  0.3887
# 21891          9.42         9.62        9.38  ...  0.0267  0.0450  0.2365
# 21892         60.02        60.67       59.75  ...  0.0437  0.6056  0.5082
# 21893        338.49       339.98      335.82  ...  0.0507  0.7483  0.6855
# 21894         26.98        27.29       26.47  ...  0.0412  0.6653  0.6553
# 21895        100.21       102.52      100.11  ...  0.0320  0.0474  0.1978
# 21896          7.67         7.72        7.64  ...  0.0430  0.0984  0.2308
# 21897         37.21        37.97       36.87  ...  0.0309  0.0687  0.2502
# 21898         82.87        83.64       82.54  ...  0.0276  0.8249  0.6176
# 21899          9.89         9.93        9.83  ...  0.0238  0.7797  0.7458
#
#         RSI10  ret5_rank  RSI2_rank  RSI5_rank  RSI10_rank  label  prediction
# 21870  0.4799     0.9978     0.1499     0.3803      0.5168     15    4.673849
# 21871  0.4388     1.0000     0.2953     0.3960      0.4295     16    4.494989
# 21872  0.2869     0.9597     0.0828     0.0671      0.0559     15    2.674231
# 21873  0.3254     0.9485     0.1432     0.0917      0.1432     15    2.349835
# 21874  0.6976     0.9821     0.9642     0.9060      0.8971     15    2.336006
# 21875  0.6285     0.9553     0.9396     0.8702      0.8121     15    2.336006
# 21876  0.7847     0.9441     0.8792     0.9799      0.9821     15    2.336006
# 21877  0.7277     0.9418     0.9553     0.9553      0.9396     15    2.336006
# 21878  0.4405     0.9843     0.4049     0.4206      0.4362     15    1.960662
# 21879  0.4887     0.9888     0.2237     0.4161      0.5369     15    1.960662
# 21880  0.4941     0.9955     0.3714     0.4698      0.5593     15    1.960662
# 21881  0.5142     0.9642     0.4541     0.5280      0.6040     15    1.960662
# 21882  0.4700     0.9776     0.4183     0.4832      0.5034     15    1.960662
# 21883  0.4070     0.9799     0.2461     0.3579      0.3557     15    1.960662
# 21884  0.4412     0.9911     0.6532     0.4609      0.4407     15    1.960662
# 21885  0.3646     0.9687     0.1477     0.2461      0.2685     15    1.960662
# 21886  0.4469     0.9575     0.3423     0.4430      0.4497     15    1.960662
# 21887  0.4897     0.9530     0.6174     0.5727      0.5436     15    1.960662
# 21888  0.5544     0.9620     0.5369     0.6376      0.6756     15    1.960662
# 21889  0.3416     0.9933     0.0089     0.0336      0.1834     15    1.960662
# 21890  0.4335     0.9732     0.2282     0.3714      0.4161     15    1.960662
# 21891  0.3037     0.9374     0.0224     0.0604      0.0872     14    1.812260
# 21892  0.4241     0.9754     0.7069     0.5347      0.3870     15    1.733547
# 21893  0.6183     0.9866     0.7718     0.7763      0.7919     15    1.733547
# 21894  0.6138     0.9664     0.7248     0.7383      0.7808     15    1.733547
# 21895  0.2611     0.9508     0.0291     0.0291      0.0268     15    1.615656
# 21896  0.2489     0.9709     0.1566     0.0537      0.0179     15    1.615656
# 21897  0.2705     0.9463     0.0604     0.0828      0.0380     15    1.615656
# 21898  0.5637     0.9396     0.8054     0.6913      0.7136     15    1.247425
# 21899  0.6372     0.9217     0.7897     0.8322      0.8210     14   -0.549572
#
# [30 rows x 22 columns]
